# %%
# using...

using PyPlot
# Out:
# INFO: Loading help data...
# ...

# %%
# sizes = NaN * zeros( length(labels) )
# explode = zeros( length(labels) )
# explode[ round( length( labels ) * rand(1) ) ] = 0.1

labels = ["Power","Transportation","Agriculture & land use","Buildings", "Manufacturing", "Consumer & service"]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "chocolate", "ivory"]
explode = zeros( length(labels) ); explode[1] = .1
sizes = [2.0, 1.9, 1.6, 1.6, 1.2, 0.7]

pct = String[]
for i = 1:length(labels)
    push!(pct, string(sizes[i]))
end
total = sum(sizes)
function pp(x)
    return @sprintf("%1.1f\n", x*total/100)
end

fig = figure(figsize=(5,5)) # 10,10
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct=pp)

axis("equal")
title("ICT abatement potential by end-use sector\n")
PyPlot.savefig("pyplot.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11694ea50>)

# %%
labels = ["Digitalization &\n dematerialization","Data collection &\n communication","System integration","Process, activity &\n functional optimization"]
sizes = [0.5, 2.3, 2.3, 4.1]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral"]
explode = zeros( length(labels) ); explode[end] = .1

pct = String[]
for i = 1:length(labels)
    push!(pct, string(sizes[i]))
end
total = sum(sizes)
function pp(x)
    return @sprintf("%1.1f\n", x*total/100)
end

fig = figure(figsize=(5,5)) # 10,10
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct=pp)

axis("equal")
title("ICT abatement potential by change lever\n")
PyPlot.savefig("pyplot1.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x12011d6d0>)

# %%
labels = ["Demand management","Time-of-day pricing","Power-load balancing","Power grid optimization", "Integration of renewables\nin power generation", "Virtual power plant", "Integration of off-grid\nrenewables and storage"]
sizes = [0.01, 0.21, 0.38, 0.33, 0.85, 0.04, 0.20]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "chocolate", "ivory", "olive"]
explode = zeros( length(labels) ); explode[1] = .2; explode[2] = .2; explode[3] = .2; explode[4] = .2; explode[5] = .2; explode[6] = .2; explode[7] = .2;

pct = String[]
for i = 1:length(labels)
    push!(pct, string(sizes[i]))
end
total = sum(sizes)
function pp(x)
    return @sprintf("%1.2f\n", x*total/100)
end

fig = figure(figsize=(5,5)) # 10,10
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct=pp)

axis("equal")
title("Power abatement potential\n")
PyPlot.savefig("pyplot2.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x116f5ae90>)

# %%
labels = ["Demand management","Time-of-day pricing","Power-load balancing","Power grid optimization", "Integration of renewables\nin power generation", "Virtual power plant", "Integration of off-grid\nrenewables and storage"]
sizes = [4, 79, 9, 143, 153, 2, 1]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "chocolate", "ivory", "olive"]
explode = zeros( length(labels) ); explode[1] = .2; explode[2] = .2; explode[3] = .2; explode[4] = .2; explode[5] = .2; explode[6] = .2; explode[7] = .2;

pct = String[]
for i = 1:length(labels)
    push!(pct, string(sizes[i]))
end
total = sum(sizes)
function pp(x)
    return @sprintf("%1.2f\n", x*total/100)
end

fig = figure(figsize=(5,5)) # 10,10
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct=pp)

axis("equal")
title("Power abatement potential in China\n")
PyPlot.savefig("pyplot2.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10cce9590>)

# %%
labels = ["Coal","Gase","Nuclear","Renewable", "Other"]
sizes = [37, 31, 20, 5, 7]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "chocolate"]
explode = zeros( length(labels) ); explode[1] = .1;

pct = String[]
for i = 1:length(labels)
    push!(pct, string(sizes[i]))
end
total = sum(sizes)
function pp(x)
    return @sprintf("%1.0f%%", x*total/100)
end

fig = figure(figsize=(5,5)) # 10,10
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct=pp)

axis("equal")
title("Fuel consumption for energy priduction in the USA\n")
PyPlot.savefig("pyplot2.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10cb7e610>)

# %%
labels = ["Demand management","Time-of-day pricing","Power-load balancing","Power grid optimization", "Integration of renewables\nin power generation", "Virtual power plant", "Integration of off-grid\nrenewables and storage"]
sizes = [21, 22, 13, 91, 197, 6, 0]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "chocolate", "ivory", "olive"]
explode = zeros( length(labels) ); explode[1] = .2; explode[2] = .2; explode[3] = .2; explode[4] = .2; explode[5] = .2; explode[6] = .2; explode[7] = .2;

pct = String[]
for i = 1:length(labels)
    push!(pct, string(sizes[i]))
end
total = sum(sizes)
function pp(x)
    return @sprintf("%1.2f\n", x*total/100)
end

fig = figure(figsize=(5,5)) # 10,10
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct=pp)

axis("equal")
title("Power abatement potential in the USA\n")
PyPlot.savefig("pyplot2.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10d078190>)
